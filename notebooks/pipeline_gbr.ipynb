# %% [markdown]
# <a href="https://colab.research.google.com/github/igornunespatricio/house-prices-advanced-regression-techniques/blob/main/pipeline_gbr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing packages

# %%
# run this if you are in google colab
# !pip install opendatasets >/dev/null
# !pip install --upgrade scikit-learn >/dev/null

# %% [markdown]
# # Importing packages

# %%
import opendatasets
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import root_mean_squared_error, make_scorer
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
import joblib

# %% [markdown]
# # Downloading data

# %%
# Before running this code, make sure to upload your kaggle.json file here, otherwise it will return an error.
opendatasets.download('https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques')
# Out:
# Skipping, found downloaded files in "./house-prices-advanced-regression-techniques" (use force=True to force download)

# %% [markdown]
# # Reading data

# %%
# Reading the database
train = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')
test = pd.read_csv('house-prices-advanced-regression-techniques/test.csv')

# %% [markdown]
# # Data Analysis

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# Many columns have null values, we know from the data description that some of them are null because they don't have the feature, for example, garage or basement, so they shouldn't be null. In this case, we can change these values to something more meaningful than just removing the rows/columns or adding the mean, median or mode.

# %%
train.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# Id                 0
# Functional         0
# Fireplaces         0
# KitchenQual        0
# KitchenAbvGr       0
# BedroomAbvGr       0
# HalfBath           0
# FullBath           0
# BsmtHalfBath       0
# TotRmsAbvGrd       0
# GarageCars         0
# dtype: int64

# %%
x = train.drop(['SalePrice', 'Id'], axis=1)
y = train['SalePrice']

# %%
# printing all columns to be passed to the model
print(*x.columns.tolist(), sep='\n')
# Out:
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# TotRmsAbvGrd
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# SaleCondition

# %%
x['LotFrontage'].isnull().value_counts(dropna=False)
# Out:
# LotFrontage
# False    1201
# True      259
# Name: count, dtype: int64

# %% [markdown]
# For the following columns we should input a "No Feature" value since as per the data description, they don't contain the feature, for example, don't contain garage, pool, basement, etc.
#
# ```
# 'PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu',
# 'GarageYrBlt', 'GarageCond', 'GarageType', 'GarageFinish', 'GarageQual',
# 'BsmtFinType2', 'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtFinType1'
# ```

# %% [markdown]
# # Pipeline

# %%
class GroupImputer(BaseEstimator, TransformerMixin):
    def __init__(self, agg_func='median'):
        self.agg_func = agg_func

    def fit(self, x, y=None):
        self.group_columns = x.select_dtypes(include='object').columns.tolist()
        self.value_columns = x.select_dtypes(include=np.number).columns.tolist()
        self.aggs = x.groupby(self.group_columns)
        return self

    def transform(self, x):
        x_transformed = x.copy()
        column = self.aggs[self.value_columns].transform(self.agg_func)
        x_transformed[self.value_columns] = x[self.value_columns].fillna(column)
        return x_transformed

    def fit_transform(self, x, y=None):
        self.fit(x)
        result = self.transform(x)
        return result

    def get_feature_names_out(self, input_features=None):
        return input_features

# building the scorer function
def rmse_of_log(y_true, y_pred):
    """
    This scorer function will calculate the RMSE of the log of predictions and true values
    """
    return root_mean_squared_error(np.log1p(y_true), np.log1p(y_pred))

# %%
train.select_dtypes(include='object').columns.tolist()
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
random_state = 42

cat_ohe_cols = [
    'MSZoning', 'Street', 'Alley', 'LandContour', 'LotConfig', #'Neighborhood'    not sure i wanna use neighborhood, to many values
    'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
    'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation',
    'Heating', 'Electrical', 'GarageType', 'MiscFeature', 'SaleType', 'SaleCondition'
]

cat_oe_cols = [
    'LotShape', 'Utilities', 'LandSlope', 'ExterQual', 'ExterCond',
    'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
    'HeatingQC', 'CentralAir', 'KitchenQual', 'Functional', 'FireplaceQu',
    'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
    'PoolQC', 'Fence'
]

cat_oe_values = [
    ['IR3', 'IR2', 'IR1', 'Regular'],  # LotShape
    ['ELO', 'NoSeWa', 'NoSewr', 'AllPub'],  # Utilities
    ['Sev', 'Mod', 'Gtl'],  # LandSlope
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],  # ExterQual
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],  # ExterCond
    ['No Feature', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],  # BsmtQual
    ['No Feature', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],  # BsmtCond
    ['No Feature', 'No', 'Mn', 'Av', 'Gd'],  # BsmtExposure
    ['No Feature', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ'],  # BsmtFinType1
    ['No Feature', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ'],  # BsmtFinType2
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],  # HeatingQc
    ['No', 'Yes'],  # CentralAir
    ['Po', 'Fa', 'TA', 'Gd', 'Ex'],  # KitchenQual
    ['Sal', 'Sev', 'Maj2', 'Maj1', 'Mod', 'Min2', 'Min1', 'Typ'],  # Functional
    ['No Feature', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],  # FireplaceQu
    ['No Feature', 'Unf', 'RFn', 'Fin'],  # GarageFinish
    ['No Feature', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],  # GarageQual
    ['No Feature', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],  # GarageCond
    ['N', 'P', 'Y'],  # PavedDrive
    ['No Feature', 'Fa', 'TA', 'Gd', 'Ex'],  #PoolQC
    ['No Feature', 'MnWw', 'GdWo', 'MnPrv', 'GdPrv'],  # Fence
]



# cat_cols = x.select_dtypes(include='object').columns.tolist()
num_cols = x.select_dtypes(include='number').columns.tolist()[1:]

ohe_pipeline = Pipeline(
    steps=[
        ('categorical_imputer_no_feature_ohe', SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='No Feature')),
        ('one_hot_encoder', OneHotEncoder(handle_unknown='infrequent_if_exist', min_frequency=0.2, sparse_output=False))

    ]
)

oe_pipeline = Pipeline(
    steps=[
        ('categorical_imputer_no_feature_oe', SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='No Feature')),
        ('ordinal_encoder', OrdinalEncoder(categories=cat_oe_values, handle_unknown='use_encoded_value', unknown_value=-1, encoded_missing_value=-1, min_frequency=0.2))
    ]
)

categorical_preprocessor = ColumnTransformer(
    transformers=[
        ('cat', ohe_pipeline, cat_ohe_cols),
        ('oe', oe_pipeline, cat_oe_cols)
    ],
    sparse_threshold=0
)

numerical_pipeline = Pipeline(
    steps=[
        ('numerical_imputer', SimpleImputer(missing_values=np.nan, strategy='median')),
        ('scaler', StandardScaler())
    ]
)

numerical_preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_pipeline, num_cols)
    ],
    sparse_threshold=0
)

feature_union = FeatureUnion(
    transformer_list=[
        ('categorical_preprocessor', categorical_preprocessor),
        ('numerical_preprocessor', numerical_preprocessor)
    ]
)

full_pipeline = Pipeline(
    steps=[
        ('feature_union', feature_union),
        ('pca', PCA(n_components=30, random_state=random_state)),
        ('regressor', GradientBoostingRegressor(random_state=random_state))
    ]
)

full_pipeline

param_grid = {
    'pca__n_components': [50, 80, 100],
    'regressor__n_estimators': [250, 300, 350],
    'regressor__max_depth': [2, 5, 8]
}

rmse_log_scorer= make_scorer(rmse_of_log, greater_is_better=False)

grid_search = GridSearchCV(full_pipeline, param_grid, cv=5, scoring=rmse_log_scorer, verbose=4)

grid_search.fit(x, y)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.144 total time=   2.0s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.165 total time=   1.3s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.153 total time=   1.3s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.144 total time=   1.3s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.139 total time=   1.3s
# [CV 1/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.145 total time=   1.5s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.164 total time=   1.6s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.153 total time=   1.8s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.145 total time=   1.9s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.139 total time=   1.5s
# [CV 1/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.146 total time=   1.7s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.165 total time=   1.7s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.154 total time=   1.7s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.147 total time=   1.7s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.141 total time=   1.9s
# [CV 1/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.146 total time=   3.0s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.156 total time=   2.6s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.154 total time=   2.6s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.140 total time=   2.6s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.151 total time=   3.2s
# [CV 1/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.146 total time=   3.2s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.157 total time=   3.1s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.154 total time=   3.0s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.141 total time=   3.7s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.151 total time=   3.0s
# [CV 1/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.146 total time=   3.5s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.157 total time=   3.5s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.154 total time=   4.1s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.141 total time=   3.6s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.152 total time=   3.6s
# [CV 1/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.153 total time=   4.4s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.175 total time=   3.7s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.159 total time=   3.7s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.152 total time=   4.3s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.159 total time=   3.9s
# [CV 1/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.153 total time=   4.4s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.175 total time=   5.0s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.159 total time=   4.4s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.152 total time=   4.4s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.159 total time=   5.0s
# [CV 1/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.153 total time=   5.1s
# [CV 2/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.175 total time=   5.7s
# [CV 3/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.159 total time=   5.2s
# [CV 4/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.152 total time=   5.3s
# [CV 5/5] END pca__n_components=10, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.159 total time=   5.7s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.140 total time=   3.1s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.174 total time=   3.1s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.141 total time=   3.7s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.138 total time=   3.1s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.143 total time=   3.1s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.140 total time=   3.8s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.175 total time=   4.1s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.140 total time=   3.6s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.138 total time=   3.7s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.143 total time=   4.2s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.141 total time=   4.2s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.179 total time=   4.2s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.140 total time=   4.8s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.139 total time=   4.2s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.143 total time=   4.3s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.137 total time=   7.3s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.149 total time=   7.3s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.140 total time=   6.8s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.136 total time=   7.3s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.149 total time=   6.8s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.137 total time=   8.6s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.149 total time=   8.7s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.139 total time=   8.0s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.136 total time=   8.6s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.150 total time=   8.7s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.137 total time=   9.4s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.149 total time=   9.9s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.140 total time=   9.9s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.136 total time=   9.9s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.150 total time=   9.6s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.147 total time=  10.5s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.168 total time=  10.6s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.154 total time=  10.6s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.143 total time=  10.7s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.161 total time=  10.6s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.147 total time=  12.6s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.168 total time=  12.6s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.154 total time=  12.6s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.143 total time=  12.6s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.161 total time=  12.6s
# [CV 1/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.147 total time=  14.6s
# [CV 2/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.168 total time=  14.6s
# [CV 3/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.154 total time=  14.6s
# [CV 4/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.143 total time=  14.6s
# [CV 5/5] END pca__n_components=30, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.161 total time=  15.0s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.138 total time=   5.1s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.155 total time=   4.9s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.144 total time=   5.4s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.136 total time=   4.8s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=250;, score=-0.139 total time=   5.3s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.137 total time=   6.0s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.156 total time=   6.0s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.144 total time=   6.2s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.135 total time=   5.9s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=300;, score=-0.138 total time=   6.3s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.136 total time=   6.9s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.157 total time=   7.1s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.144 total time=   7.2s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.136 total time=   6.9s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=2, regressor__n_estimators=350;, score=-0.139 total time=   7.6s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.131 total time=  11.5s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.144 total time=  11.4s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.142 total time=  11.3s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.127 total time=  11.5s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=250;, score=-0.153 total time=  11.5s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.130 total time=  13.7s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.144 total time=  13.9s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.142 total time=  14.0s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.127 total time=  13.8s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=300;, score=-0.153 total time=  13.8s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.131 total time=  15.8s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.144 total time=  15.8s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.142 total time=  16.1s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.126 total time=  16.2s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=5, regressor__n_estimators=350;, score=-0.153 total time=  15.9s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.150 total time=  17.1s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.158 total time=  17.5s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.156 total time=  16.9s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.144 total time=  17.2s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=250;, score=-0.166 total time=  17.2s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.150 total time=  20.8s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.158 total time=  21.3s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.156 total time=  20.8s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.144 total time=  20.5s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=300;, score=-0.166 total time=  20.6s
# [CV 1/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.150 total time=  24.2s
# [CV 2/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.158 total time=  24.0s
# [CV 3/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.156 total time=  23.9s
# [CV 4/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.144 total time=  24.0s
# [CV 5/5] END pca__n_components=50, regressor__max_depth=8, regressor__n_estimators=350;, score=-0.166 total time=  24.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('feature_union',
#                                         FeatureUnion(transformer_list=[('categorical_preprocessor',
#                                                                         ColumnTransformer(sparse_threshold=0,
#                                                                                           transformers=[('cat',
#                                                                                                          Pipeline(steps=[('categorical_imputer_no_feature_ohe',
#                                                                                                                           SimpleImputer(fill_value='No '
#                                                                                                                                                    'Feature',
#                                                                                                                                         strategy='constant')),
#                                                                                                                          ('one_hot_encoder',
#                                                                                                                           OneHotEncoder(handle_unknown='infreque...
#                                                                                                           'EnclosedPorch',
#                                                                                                           '3SsnPorch', ...])]))])),
#                                        ('pca',
#                                         PCA(n_components=30, random_state=42)),
#                                        ('regressor',
#                                         GradientBoostingRegressor(random_state=42))]),
#              param_grid={'pca__n_components': [10, 30, 50],
#                          'regressor__max_depth': [2, 5, 8],
#                          'regressor__n_estimators': [250, 300, 350]},
#              scoring=make_scorer(rmse_of_log, greater_is_better=False, response_method='predict'),
#              verbose=4)

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score', ascending=True).head(10)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 22      13.797321      0.093872         0.028051        0.006394
# 23      15.951511      0.156335         0.026603        0.007332
# 21      11.415235      0.111776         0.024893        0.004013
# 19       6.040935      0.160820         0.024759        0.006685
# 12       7.076231      0.235812         0.025259        0.005658
# 13       8.503559      0.240600         0.024600        0.003591
# 14       9.731916      0.239930         0.027196        0.007216
# 20       7.088191      0.260589         0.031878        0.008470
# 18       5.074415      0.239177         0.023425        0.004884
# 9        3.178051      0.247644         0.020198        0.000616
#
#    param_pca__n_components param_regressor__max_depth  \
# 22                      50                          5
# 23                      50                          5
# 21                      50                          5
# 19                      50                          2
# 12                      30                          5
# 13                      30                          5
# 14                      30                          5
# 20                      50                          2
# 18                      50                          2
# 9                       30                          2
#
#    param_regressor__n_estimators  \
# 22                           300
# 23                           350
# 21                           250
# 19                           300
# 12                           250
# 13                           300
# 14                           350
# 20                           350
# 18                           250
# 9                            250
#
#                                                params  split0_test_score  \
# 22  {'pca__n_components': 50, 'regressor__max_dept...          -0.130455
# 23  {'pca__n_components': 50, 'regressor__max_dept...          -0.130506
# 21  {'pca__n_components': 50, 'regressor__max_dept...          -0.130551
# 19  {'pca__n_components': 50, 'regressor__max_dept...          -0.136811
# 12  {'pca__n_components': 30, 'regressor__max_dept...          -0.137170
# 13  {'pca__n_components': 30, 'regressor__max_dept...          -0.137131
# 14  {'pca__n_components': 30, 'regressor__max_dept...          -0.137266
# 20  {'pca__n_components': 50, 'regressor__max_dept...          -0.135796
# 18  {'pca__n_components': 50, 'regressor__max_dept...          -0.137823
# 9   {'pca__n_components': 30, 'regressor__max_dept...          -0.140034
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 22          -0.144058          -0.141783          -0.126539
# 23          -0.144175          -0.141685          -0.126473
# 21          -0.144040          -0.141886          -0.126711
# 19          -0.155766          -0.144202          -0.135432
# 12          -0.149015          -0.139525          -0.135575
# 13          -0.148854          -0.139453          -0.135666
# 14          -0.148818          -0.139540          -0.135531
# 20          -0.157284          -0.144205          -0.135764
# 18          -0.154863          -0.143910          -0.135949
# 9           -0.173518          -0.140538          -0.138234
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 22          -0.153002        -0.139167        0.009566                1
# 23          -0.153055        -0.139179        0.009596                2
# 21          -0.153095        -0.139257        0.009534                3
# 19          -0.138449        -0.142132        0.007443                4
# 12          -0.149397        -0.142136        0.005909                5
# 13          -0.149595        -0.142140        0.005914                6
# 14          -0.149591        -0.142149        0.005904                7
# 20          -0.138532        -0.142316        0.008092                8
# 18          -0.139362        -0.142381        0.006774                9
# 9           -0.142665        -0.146998        0.013335               10

# %%
grid_search.best_params_
# Out:
# {'pca__n_components': 50,
#  'regressor__max_depth': 5,
#  'regressor__n_estimators': 300}

# %% [markdown]
# Looking at the hyperparameters, there is still room for improvment since the best choice for n_components from PCA was 50 the top value from the list. We can increase the number components and train again.

# %%
joblib.dump(grid_search, 'pipeline_gbr.pkl')
# Out:
# ['pipeline_gbr.pkl']

# %% [markdown]
# # Submitting result to Kaggle

# %%
model_saved = joblib.load('/content/pipeline_gbr.pkl')

# %%
model_saved
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('feature_union',
#                                         FeatureUnion(transformer_list=[('categorical_preprocessor',
#                                                                         ColumnTransformer(sparse_threshold=0,
#                                                                                           transformers=[('cat',
#                                                                                                          Pipeline(steps=[('categorical_imputer_no_feature_ohe',
#                                                                                                                           SimpleImputer(fill_value='No '
#                                                                                                                                                    'Feature',
#                                                                                                                                         strategy='constant')),
#                                                                                                                          ('one_hot_encoder',
#                                                                                                                           OneHotEncoder(handle_unknown='infreque...
#                                                                                                           'EnclosedPorch',
#                                                                                                           '3SsnPorch', ...])]))])),
#                                        ('pca',
#                                         PCA(n_components=30, random_state=42)),
#                                        ('regressor',
#                                         GradientBoostingRegressor(random_state=42))]),
#              param_grid={'pca__n_components': [10, 30, 50],
#                          'regressor__max_depth': [2, 5, 8],
#                          'regressor__n_estimators': [250, 300, 350]},
#              scoring=make_scorer(rmse_of_log, greater_is_better=False, response_method='predict'),
#              verbose=4)

# %%
predictions = model_saved.predict(test.drop('Id', axis=1))

# %%
test_predictions = pd.DataFrame(
    {
        'Id': test.Id,
        'SalePrice': predictions
    }
)

test_predictions. head(5)
# Out:
#      Id      SalePrice
# 0  1461  128982.278412
# 1  1462  163259.622628
# 2  1463  184425.504053
# 3  1464  187342.210872
# 4  1465  175428.710329

# %%
test_predictions.to_csv('pipeline_gradient_boosting_regressor_predictions.csv', index=False)

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions submit -c house-prices-advanced-regression-techniques -f /content/pipeline_gradient_boosting_regressor_predictions.csv -m "Gradient Boosting Regressor with Pipeline, One Hot Encoder, Ordinal Encoder and 50 components in PCA"
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.12 / client 1.5.16)
# 100% 33.7k/33.7k [00:00<00:00, 54.2kB/s]
# Successfully submitted to House Prices - Advanced Regression Techniques
